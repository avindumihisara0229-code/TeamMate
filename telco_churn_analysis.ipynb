# %% [markdown]
# <a href="https://colab.research.google.com/github/avindumihisara0229-code/TeamMate/blob/master/telco_churn_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
